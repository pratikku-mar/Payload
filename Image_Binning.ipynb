# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
img = cv2.imread('ClockTower.jpg')

# %%
imgn=np.asarray(Image.fromarray(img).reduce(4))
imgne = cv2.cvtColor(imgn, cv2.COLOR_BGR2RGB)

plt.imshow(imgne)
